# %% [markdown]
# <a href="https://colab.research.google.com/github/akashh005/Netflix_Business_case_EDA/blob/main/Netflix_BC_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **About NETFLIX**
#
# Netflix is one of the most popular media and video streaming platforms. They have over 10000 movies or tv shows available on their platform, as of mid-2021, they have over 222M Subscribers globally. This tabular dataset consists of listings of all the movies and tv shows available on Netflix, along with details such as - cast, directors, ratings, release year, duration, etc.
#
# # **Business Problem**
#
# Analyze the data and generate insights that could help Netflix ijn deciding which type of shows/movies to produce and how they can grow the business in different countries
#
#
# **The dataset provided to you consists of a list of all the TV shows/movies available on Netflix:**
#
# Show_id: Unique ID for every Movie / Tv Show
# Type: Identifier - A Movie or TV Show
# Title: Title of the Movie / Tv Show
# Director: Director of the Movie
# Cast: Actors involved in the movie/show
# Country: Country where the movie/show was produced
# Date_added: Date it was added on Netflix
# Release_year: Actual Release year of the movie/show
# Rating: TV Rating of the movie/show
# Duration: Total Duration - in minutes or number of seasons
# Listed_in: Genre
# Description: The summary description

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import warnings
warnings.simplefilter('ignore')

# %%
# importing libraries -
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# reading the data file -
df=pd.read_csv('/content/drive/MyDrive/netflix.csv')
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.sample(10)
# Out:
#      show_id     type                              title           director  \
# 4034   s4035    Movie                             Lady J    Emmanuel Mouret
# 6134   s6135    Movie                  American Assassin     Michael Cuesta
# 8028   s8029    Movie                        Sister Code        Corey Grant
# 1030   s1031    Movie    Four Sisters Before the Wedding   Mae Czarina Cruz
# 8720   s8721  TV Show          What Happens to My Family                NaN
# 1951   s1952  TV Show                    A Perfect Crime                NaN
# 39       s40  TV Show                       Chhota Bheem                NaN
# 7442   s7443    Movie                       Men in Black   Barry Sonnenfeld
# 2018   s2019    Movie  Bhai: Vyakti Ki Valli - Uttarardh   Mahesh Manjrekar
# 6403   s6404    Movie                     Calendar Girls  Madhur Bhandarkar
#
#                                                    cast        country  \
# ...

# %%
# shape of the data
df.shape
# Out:
# (8807, 12)

# %%
# checking the type of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
# statistical summary
df.describe(include='all').T
# Out:
#                count unique  \
# show_id         8807   8807
# type            8807      2
# title           8807   8807
# director        6173   4528
# cast            7982   7692
# country         7976    748
# date_added      8797   1767
# release_year  8807.0    NaN
# rating          8803     17
# duration        8804    220
# listed_in       8807    514
# description     8807   8775
#
#                                                             top  freq  \
# show_id                                                      s1     1
# type                                                      Movie  6131
# title                                      Dick Johnson Is Dead     1
# director                                          Rajiv Chilaka    19
# cast                                         David Attenborough    19
# country                                           United States  2818
# date_added                                      January 1, 2020   109
# ...

# %%
# checking null values -
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
# # checking the % of movies vs tv shows
df['type'].value_counts(normalize=True) * 100
# Out:
# type
# Movie      69.615079
# TV Show    30.384921
# Name: proportion, dtype: float64

# %%
sns.countplot(data=df, x='type')
plt.show()

# %% [markdown]
# # **Unnesting the data**

# %%
# unnesting the directors column -
constraint1=df['director'].apply(lambda x: str(x).split(', ')).tolist()
df_new1=pd.DataFrame(constraint1, index=df['title'])
df_new1=df_new1.stack()
df_new1=pd.DataFrame(df_new1.reset_index())
df_new1.rename(columns={0:'Director'}, inplace=True)
df_new1.drop(['level_1'], axis=1, inplace=True)
df_new1.head()
# Out:
#                    title         Director
# 0   Dick Johnson Is Dead  Kirsten Johnson
# 1          Blood & Water              nan
# 2              Ganglands  Julien Leclercq
# 3  Jailbirds New Orleans              nan
# 4           Kota Factory              nan

# %%
# unnesting the cast column -
constraint2=df['cast'].apply(lambda x: str(x).split(', ')).tolist()
df_new2=pd.DataFrame(constraint2, index=df['title'])
df_new2=df_new2.stack()
df_new2=pd.DataFrame(df_new2.reset_index())
df_new2.rename(columns={0:'Cast'}, inplace=True)
df_new2.drop(['level_1'], axis=1, inplace=True)
df_new2.head()
# Out:
#                   title            Cast
# 0  Dick Johnson Is Dead             nan
# 1         Blood & Water      Ama Qamata
# 2         Blood & Water     Khosi Ngema
# 3         Blood & Water   Gail Mabalane
# 4         Blood & Water  Thabang Molaba

# %%
# unnesting the listed_in column -
constraint3=df['listed_in'].apply(lambda x: str(x).split(', ')).tolist()
df_new3=pd.DataFrame(constraint3, index=df['title'])
df_new3=df_new3.stack()
df_new3=pd.DataFrame(df_new3.reset_index())
df_new3.rename(columns={0:'Genre'}, inplace=True)
df_new3.drop(['level_1'], axis=1, inplace=True)
df_new3.head()
# Out:
#                   title                   Genre
# 0  Dick Johnson Is Dead           Documentaries
# 1         Blood & Water  International TV Shows
# 2         Blood & Water               TV Dramas
# 3         Blood & Water            TV Mysteries
# 4             Ganglands          Crime TV Shows

# %%
# Checking How many movies and Tv Shows has been produced for each Genre
df_new3.groupby(['Genre']).agg({"title":"nunique"}).reset_index().sort_values(by=['title'],
                                                                                 ascending=False)
# Out:
#                            Genre  title
# 16          International Movies   2752
# 12                        Dramas   2427
# 7                       Comedies   1674
# 17        International TV Shows   1351
# 10                 Documentaries    869
# 0             Action & Adventure    859
# 34                     TV Dramas    763
# 15            Independent Movies    756
# 4       Children & Family Movies    641
# 24               Romantic Movies    616
# 33                   TV Comedies    581
# 41                     Thrillers    577
# 8                 Crime TV Shows    470
# 18                      Kids' TV    451
# 11                    Docuseries    395
# 22              Music & Musicals    375
# 25             Romantic TV Shows    370
# 14                 Horror Movies    357
# 30               Stand-Up Comedy    343
# 23                    Reality TV    255
# 3               British TV Shows    253
# 26              Sci-Fi & Fantasy    243
# ...

# %%
# there are too many Genre with the comedy name. so combining them and checking the comedy genre.
dfx = df_new3[df_new3['Genre'].isin(['Comedies', 'TV Comedies', 'Stand-Up Comedy', 'Stand-Up Comedy & Talk Shows'])]
len(dfx)
# Out:
# 2654

# %%
# unnesting the country column -
constraint4=df['country'].apply(lambda x: str(x).split(', ')).tolist()
df_new4=pd.DataFrame(constraint4, index=df['title'])
df_new4=df_new4.stack()
df_new4=pd.DataFrame(df_new4.reset_index())
df_new4.rename(columns={0:'Country'}, inplace=True)
df_new4.drop(['level_1'], axis=1, inplace=True)
df_new4.head(20)
# Out:
#                                   title         Country
# 0                  Dick Johnson Is Dead   United States
# 1                         Blood & Water    South Africa
# 2                             Ganglands             nan
# 3                 Jailbirds New Orleans             nan
# 4                          Kota Factory           India
# 5                         Midnight Mass             nan
# 6      My Little Pony: A New Generation             nan
# 7                               Sankofa   United States
# 8                               Sankofa           Ghana
# 9                               Sankofa    Burkina Faso
# 10                              Sankofa  United Kingdom
# 11                              Sankofa         Germany
# 12                              Sankofa        Ethiopia
# 13        The Great British Baking Show  United Kingdom
# 14                         The Starling   United States
# 15  Vendetta: Truth, Lies and The Mafia             nan
# ...

# %%
# checking which country has produced the most movies and Tv shows
mtv = df_new4.groupby(['Country']).agg({"title":"nunique"}).reset_index().sort_values(by=['title'],
                                                                                 ascending=False)[:10]
mtv
# Out:
#             Country  title
# 119   United States   3689
# 47            India   1046
# 127             nan    831
# 117  United Kingdom    804
# 22           Canada    445
# 38           France    393
# 55            Japan    318
# 105           Spain    232
# 103     South Korea    231
# 40          Germany    226

# %%
# top 10 countries
df_new4['Country'].value_counts().sort_values(ascending=False)[:10]
# Out:
# Country
# United States     3689
# India             1046
# nan                831
# United Kingdom     804
# Canada             445
# France             393
# Japan              318
# Spain              232
# South Korea        231
# Germany            226
# Name: count, dtype: int64

# %% [markdown]
# **Merging the unnested columns**

# %%
# merging the unnested director data with unnested cast data
df_new5=df_new2.merge(df_new1, on=['title'], how='inner')
# merging the above merged data with unnested genre data
df_new6=df_new5.merge(df_new3, on=['title'], how='inner')
# merging the above merged data with unnested country data
df_new=df_new6.merge(df_new4, on=['title'], how='inner')

# replacing nan values of director and cast by Unknown
df_new['Cast'].replace(['nan'], ['Unknown'], inplace=True)
df_new['Director'].replace(['nan'], ['Unknown'], inplace=True)
df_new['Country'].replace(['nan'], [np.nan], inplace=True)

df_new.head()
# Out:
#                   title         Cast         Director                   Genre  \
# 0  Dick Johnson Is Dead      Unknown  Kirsten Johnson           Documentaries
# 1         Blood & Water   Ama Qamata          Unknown  International TV Shows
# 2         Blood & Water   Ama Qamata          Unknown               TV Dramas
# 3         Blood & Water   Ama Qamata          Unknown            TV Mysteries
# 4         Blood & Water  Khosi Ngema          Unknown  International TV Shows
#
#          Country
# 0  United States
# 1   South Africa
# 2   South Africa
# 3   South Africa
# 4   South Africa

# %% [markdown]
# # **Merging the above data to the original data to get the final data for Analysis**

# %%
# merging our unnested data with the original data
df_final=df_new.merge(df[['show_id', 'type', 'title', 'date_added',
                          'release_year', 'rating', 'duration']],
                          on=['title'], how='left')
df_final.head()
# Out:
#                   title         Cast         Director                   Genre  \
# 0  Dick Johnson Is Dead      Unknown  Kirsten Johnson           Documentaries
# 1         Blood & Water   Ama Qamata          Unknown  International TV Shows
# 2         Blood & Water   Ama Qamata          Unknown               TV Dramas
# 3         Blood & Water   Ama Qamata          Unknown            TV Mysteries
# 4         Blood & Water  Khosi Ngema          Unknown  International TV Shows
#
#          Country show_id     type          date_added  release_year rating  \
# 0  United States      s1    Movie  September 25, 2021          2020  PG-13
# 1   South Africa      s2  TV Show  September 24, 2021          2021  TV-MA
# 2   South Africa      s2  TV Show  September 24, 2021          2021  TV-MA
# 3   South Africa      s2  TV Show  September 24, 2021          2021  TV-MA
# 4   South Africa      s2  TV Show  September 24, 2021          2021  TV-MA
#
#     duration
# 0     90 min
# 1  2 Seasons
# ...

# %%
# checking null values again -
df_final.isna().sum() * 100.00 / df_final.shape[0]
# Out:
# title           0.000000
# Cast            0.000000
# Director        0.000000
# Genre           0.000000
# Country         5.889866
# show_id         0.000000
# type            0.000000
# date_added      0.078221
# release_year    0.000000
# rating          0.033170
# duration        0.001485
# dtype: float64

# %% [markdown]
# # **Handling Null values**

# %%
# there are very small null values present the duration rating and release year column
# so dropping them
df_final.dropna(subset=['duration', 'rating', 'release_year'], axis=0, inplace=True)

# %%
# country has many null values so replacing them by 'Unknown' to avoid the  loss of the data
df_final['Country'].fillna(df_final['Country'].value_counts().idxmax(), inplace=True)

# %%
# extracting the Year from date_added column for year wise analysis
# number of movies and shows added in each year
df_final['year_added']=df_final['date_added'].str.split(',', expand=True)[1]
df_final['year_added'].value_counts()
# Out:
# year_added
#  2019    46970
#  2020    46025
#  2021    36516
#  2018    35770
#  2017    25199
#  2016     8523
#  2015     1560
#  2014      450
#  2011      438
#  2013      207
#  2012       36
#  2009       30
#  2010       20
#  2008       19
# Name: count, dtype: int64

# %%
df_final.head(3)
# Out:
#                   title        Cast         Director                   Genre  \
# 0  Dick Johnson Is Dead     Unknown  Kirsten Johnson           Documentaries
# 1         Blood & Water  Ama Qamata          Unknown  International TV Shows
# 2         Blood & Water  Ama Qamata          Unknown               TV Dramas
#
#          Country show_id     type          date_added  release_year rating  \
# 0  United States      s1    Movie  September 25, 2021          2020  PG-13
# 1   South Africa      s2  TV Show  September 24, 2021          2021  TV-MA
# 2   South Africa      s2  TV Show  September 24, 2021          2021  TV-MA
#
#     duration year_added
# 0     90 min       2021
# 1  2 Seasons       2021
# 2  2 Seasons       2021

# %% [markdown]
# # **Univariate analysis Seperately for Movies and TV Shows**

# %%
# creating seperate dataframes for movies & TV shows -
df_shows=df_final[df_final['type']=='TV Show']
df_movies=df_final[df_final['type']=='Movie']

# %%
# which rating has been given to most of the movies
m_rat = df_movies.groupby(['rating']).agg({"title":"nunique"}).reset_index().sort_values(by=['title'], ascending=False)[:10]
m_rat
# Out:
#    rating  title
# 8   TV-MA   2062
# 6   TV-14   1427
# 5       R    797
# 9   TV-PG    540
# 4   PG-13    490
# 3      PG    287
# 11  TV-Y7    139
# 10   TV-Y    131
# 7    TV-G    126
# 2      NR     75

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=m_rat, y='rating', x='title')
plt.ylabel('Rating')
plt.xlabel('Title')
plt.title('top 10 Rating to movies')
plt.show()

# %%
# which rating has been given to most of Tv shows
s_rat = df_shows.groupby(['rating']).agg({"title":"nunique"}).reset_index().sort_values(by=['title'],
                                                                                ascending=False)[:10]

s_rat
# Out:
#      rating  title
# 4     TV-MA   1145
# 2     TV-14    733
# 5     TV-PG    323
# 7     TV-Y7    195
# 6      TV-Y    176
# 3      TV-G     94
# 0        NR      5
# 1         R      2
# 8  TV-Y7-FV      1

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=s_rat, y='rating', x='title')
plt.ylabel('Rating')
plt.xlabel('Title')
plt.title('top 10 Rating to Tv shows')
plt.show()

# %%
# duration of most of the movies
df_movies.groupby(['duration']).agg({"title":"nunique"}).reset_index().sort_values(by=['title'],
                                                                                   ascending=False)
# Out:
#     duration  title
# 195   90 min    152
# 198   93 min    146
# 199   94 min    146
# 202   97 min    146
# 196   91 min    144
# ..       ...    ...
# 124  253 min      1
# 127  273 min      1
# 130    3 min      1
# 133  312 min      1
# 102  196 min      1
#
# [205 rows x 2 columns]

# %%
df_movies['duration'].str.split(expand=True)
# Out:
#           0    1
# 0        90  min
# 159      91  min
# 160      91  min
# 161      91  min
# 162      91  min
# ...     ...  ...
# 201986  111  min
# 201987  111  min
# 201988  111  min
# 201989  111  min
# 201990  111  min
#
# [145831 rows x 2 columns]

# %%
# average duration of movies
df_movies['duration'] = df_movies['duration'].str.split(expand=True)[0]
df_movies['duration'].astype(int).mean().round()
# Out:
# 107.0

# %%
# average seasons of TV Shows
df_shows['duration'] = df_shows['duration'].str.split(expand=True)[0]
df_shows['duration'].astype(int).mean().round()
# Out:
# 2.0

# %%
# extracting the numerical value from duration for better analysis
df_movies['_duration']=df_movies['duration'].str.split(expand=True)[0]
df_movies['_duration']=df_movies['_duration'].astype(int)

# %%
# creating bins for duration to give a specific category for better analysis
bins = [1, 50, 80, 100, 120, 150, 200, 315]
labels = ['1-50', '50-80', '80-100', '100-120', '120-150', '150-200', '200-315']

df_movies['duration_bins']=pd.cut(df_movies['_duration'], bins=bins, labels=labels)
df_movies.head()
# Out:
#                                 title             Cast         Director  \
# 0                Dick Johnson Is Dead          Unknown  Kirsten Johnson
# 159  My Little Pony: A New Generation  Vanessa Hudgens    Robert Cullen
# 160  My Little Pony: A New Generation  Vanessa Hudgens   José Luis Ucha
# 161  My Little Pony: A New Generation     Kimiko Glenn    Robert Cullen
# 162  My Little Pony: A New Generation     Kimiko Glenn   José Luis Ucha
#
#                         Genre        Country show_id   type  \
# 0               Documentaries  United States      s1  Movie
# 159  Children & Family Movies  United States      s7  Movie
# 160  Children & Family Movies  United States      s7  Movie
# 161  Children & Family Movies  United States      s7  Movie
# 162  Children & Family Movies  United States      s7  Movie
#
#              date_added  release_year rating duration year_added  _duration  \
# 0    September 25, 2021          2020  PG-13       90       2021         90
# ...

# %%
# duration bins vs title
df_movies.groupby(['duration_bins']).agg({"title":"nunique"}).reset_index().sort_values(by=['title'],
                                                                                        ascending=False)
# Out:
#   duration_bins  title
# 2        80-100   2221
# 3       100-120   1671
# 4       120-150    897
# 1         50-80    806
# 0          1-50    286
# 5       150-200    226
# 6       200-315     19

# %%
# checking how many tv shows are of how many seasons
df_shows.groupby(['duration']).agg({"title":"nunique"}).reset_index().sort_values(by=['title'],
                                                                                ascending=False)
# Out:
#    duration  title
# 0         1   1791
# 7         2    425
# 8         3    199
# 9         4     95
# 10        5     65
# 11        6     33
# 12        7     23
# 13        8     17
# 14        9      9
# 1        10      7
# 4        13      3
# 2        11      2
# 3        12      2
# 5        15      2
# 6        17      1

# %%
df_final.head()
# Out:
#                   title         Cast         Director                   Genre  \
# 0  Dick Johnson Is Dead      Unknown  Kirsten Johnson           Documentaries
# 1         Blood & Water   Ama Qamata          Unknown  International TV Shows
# 2         Blood & Water   Ama Qamata          Unknown               TV Dramas
# 3         Blood & Water   Ama Qamata          Unknown            TV Mysteries
# 4         Blood & Water  Khosi Ngema          Unknown  International TV Shows
#
#          Country show_id     type          date_added  release_year rating  \
# 0  United States      s1    Movie  September 25, 2021          2020  PG-13
# 1   South Africa      s2  TV Show  September 24, 2021          2021  TV-MA
# 2   South Africa      s2  TV Show  September 24, 2021          2021  TV-MA
# 3   South Africa      s2  TV Show  September 24, 2021          2021  TV-MA
# 4   South Africa      s2  TV Show  September 24, 2021          2021  TV-MA
#
#     duration year_added
# ...

# %%
df_final1=df_final.copy(deep=True)

# %%
# checking the tv shows with each Genre
s_gnr = df_shows.groupby(['Genre']).agg({"title":"nunique"}).reset_index().sort_values(by=['title'],
                                                                               ascending=False)
s_gnr
# Out:
#                            Genre  title
# 5         International TV Shows   1350
# 15                     TV Dramas    763
# 14                   TV Comedies    580
# 3                 Crime TV Shows    470
# 6                       Kids' TV    450
# 4                     Docuseries    395
# 9              Romantic TV Shows    370
# 8                     Reality TV    255
# 1               British TV Shows    253
# 0                   Anime Series    175
# 11     Spanish-Language TV Shows    174
# 13         TV Action & Adventure    168
# 7                Korean TV Shows    151
# 17                  TV Mysteries     98
# 10           Science & Nature TV     92
# 18           TV Sci-Fi & Fantasy     84
# 16                     TV Horror     75
# 21                 Teen TV Shows     69
# 20                  TV Thrillers     57
# 12  Stand-Up Comedy & Talk Shows     56
# 2              Classic & Cult TV     28
# 19                      TV Shows     16

# %%
plt.figure(figsize=(15,5))
sns.barplot(data=s_gnr, y='title', x='Genre')
plt.ylabel('title')
plt.xlabel('Genre')
plt.title('Genre Vs TV Shows')
plt.xticks(rotation=90)
plt.show()

# %%
# checking the movies with each Genre
m_gnr = df_movies.groupby(['Genre']).agg({"title":"nunique"}).reset_index().sort_values(by=['title'],
                                                                                ascending=False)
m_gnr
# Out:
#                        Genre  title
# 11      International Movies   2752
# 7                     Dramas   2426
# 4                   Comedies   1674
# 6              Documentaries    869
# 0         Action & Adventure    859
# 10        Independent Movies    756
# 2   Children & Family Movies    641
# 15           Romantic Movies    616
# 19                 Thrillers    577
# 14          Music & Musicals    375
# 9              Horror Movies    357
# 18           Stand-Up Comedy    343
# 16          Sci-Fi & Fantasy    243
# 17             Sports Movies    219
# 3             Classic Movies    116
# 12              LGBTQ Movies    102
# 5                Cult Movies     71
# 1             Anime Features     71
# 8       Faith & Spirituality     65
# 13                    Movies     53

# %%
plt.figure(figsize=(15,5))
sns.barplot(data=m_gnr, y='title', x='Genre')
plt.ylabel('title')
plt.xlabel('Genre')
plt.title('Genre Vs Movies')
plt.xticks(rotation=90)
plt.show()

# %%
# top countries which produced most number of tv shows
s_ctry = df_shows.groupby(['Country']).agg({"title":"nunique"}).reset_index().sort_values(by=['title'],
                                                                                 ascending=False)[:10]
s_ctry
# Out:
#            Country  title
# 63   United States   1329
# 62  United Kingdom    272
# 30           Japan    198
# 52     South Korea    170
# 8           Canada    126
# 19          France     90
# 25           India     84
# 57          Taiwan     70
# 2        Australia     65
# 53           Spain     61

# %%
plt.figure(figsize=(15,5))
sns.barplot(data=s_ctry, y='Country', x='title')
plt.xlabel('title')
plt.ylabel('Countries')
plt.title('Top 10 Countries to produce Most Shows')

plt.show()

# %%
# top countries which produced most number of movies
m_ctry = df_movies.groupby(['Country']).agg({"title":"nunique"}).reset_index().sort_values(by=['title'],
                                                                                  ascending=False)[:10]

m_ctry
# Out:
#             Country  title
# 114   United States   3187
# 43            India    962
# 112  United Kingdom    532
# 20           Canada    319
# 34           France    303
# 36          Germany    182
# 100           Spain    171
# 51            Japan    119
# 23            China    114
# 65           Mexico    111

# %%
plt.figure(figsize=(15,5))
sns.barplot(data=m_ctry, y='Country', x='title')
plt.xlabel('title')
plt.ylabel('Countries')
plt.title('Top 10 Countries to produce Most Movies')

plt.show()

# %%
# checking top 10 actor/actress which has appeared for the most number of movies
df_cast=df_movies.groupby(['Cast']).agg({"title":"nunique"}).reset_index().sort_values(by=['title'],ascending=False)[:10]
df_cast=df_cast[df_cast['Cast']!='Unknown']
df_cast
# Out:
#                    Cast  title
# 2102        Anupam Kher     42
# 21774    Shah Rukh Khan     35
# 17187  Naseeruddin Shah     32
# 18058           Om Puri     30
# 638        Akshay Kumar     30
# 18322      Paresh Rawal     28
# 1311   Amitabh Bachchan     28
# 12026     Julie Tejwani     28
# 20685      Rupa Bhimani     27

# %%
plt.figure(figsize=(15,5))
sns.barplot(data=df_cast, y='Cast', x='title')
plt.xlabel('title')
plt.ylabel('Cast')
plt.title('Top 10 Cast to appear in Most Movies')

plt.show()

# %%
# checking top 10 actor/actress which has appeared for the most number of tv shows
s_cast=df_shows.groupby(['Cast']).agg({"title":"nunique"}).reset_index().sort_values(by=['title'],
                                                                                      ascending=False)[:10]
s_cast=df_cast[df_cast['Cast']!='Unknown']
s_cast
# Out:
#                    Cast  title
# 2102        Anupam Kher     42
# 21774    Shah Rukh Khan     35
# 17187  Naseeruddin Shah     32
# 18058           Om Puri     30
# 638        Akshay Kumar     30
# 18322      Paresh Rawal     28
# 1311   Amitabh Bachchan     28
# 12026     Julie Tejwani     28
# 20685      Rupa Bhimani     27

# %%
plt.figure(figsize=(15,5))
sns.barplot(data=s_cast, y='Cast', x='title')
plt.xlabel('title')
plt.ylabel('Cast')
plt.title('Top 10 Cast to appear in Most TV Shows')

plt.show()

# %%
# checking which director has directed most number of Tv Shows
df_director=df_shows.groupby(['Director']).agg({"title":"nunique"}).reset_index().sort_values(by=['title'],
                                                                                              ascending=False)
df_director=df_director[df_director['Director']!='Unknown']
df_director.head(10)
# Out:
#                   Director  title
# 146              Ken Burns      3
# 8      Alastair Fothergill      3
# 259            Stan Lathan      2
# 128          Joe Berlinger      2
# 100            Hsu Fu-chun      2
# 84   Gautham Vasudev Menon      2
# 103         Iginio Straffi      2
# 168            Lynn Novick      2
# 251            Shin Won-ho      2
# 235        Rob Seidenglanz      2

# %%
# checking which director has directed most number of movies
df_director=df_movies.groupby(['Director']).agg({"title":"nunique"}).reset_index().sort_values(by=['title'],
                                                                                               ascending=False)
df_director=df_director[df_director['Director']!='Unknown']
df_director.head(10)
# Out:
#                  Director  title
# 3580        Rajiv Chilaka     22
# 1816            Jan Suter     21
# 3631          Raúl Campos     19
# 4259          Suhas Kadav     16
# 2737         Marcus Raboy     15
# 1861            Jay Karas     15
# 726   Cathy Garcia-Molina     13
# 2813      Martin Scorsese     12
# 1858          Jay Chapman     12
# 4724      Youssef Chahine     12

# %%
# checking any downfall or rise of movies on netflix.
df_year=df_movies.groupby(['year_added']).agg({"title":"nunique"}).reset_index()
sns.lineplot(data=df_year, x='year_added', y='title')
plt.ylabel("Movies Released in the Year")
plt.xlabel("Year")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Insights
# * from year 2014 to 2019 there was a sudden rise in number of movies on netflix.
# * from year 2019 there has been a sudden downfall in number of movies on netflix.
# * in 2019 movies were on peak.
# * possible reason for downfall can be covid-19.

# %%
# checking any downfall or rise of TV Shows on netflix.
df_year=df_shows.groupby(['year_added']).agg({"title":"nunique"}).reset_index()
sns.lineplot(data=df_year, x='year_added', y='title')
plt.ylabel("Shows Released in the Year")
plt.xlabel("Year")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Insights
#
#
# *   sudden increase is seen after 2015 for TV shows
# *   even after 2019 TV shows on netflix was stable for a year
# *   downfall for tv shows is seen after 2020 but not as much as for movies

# %%
df_final.head(1)
# Out:
#                   title     Cast         Director          Genre  \
# 0  Dick Johnson Is Dead  Unknown  Kirsten Johnson  Documentaries
#
#          Country show_id   type          date_added  release_year rating  \
# 0  United States      s1  Movie  September 25, 2021          2020  PG-13
#
#   duration year_added
# 0   90 min       2021

# %%
df_final['Month'] = df_final['date_added'].str.split(' ', expand=True)[0]
df_final['Month'].str.strip()
# Out:
# 0         September
# 1         September
# 2         September
# 3         September
# 4         September
#             ...
# 201986        March
# 201987        March
# 201988        March
# 201989        March
# 201990        March
# Name: Month, Length: 201921, dtype: object

# %%
df_final.head(1)
# Out:
#                   title     Cast         Director          Genre  \
# 0  Dick Johnson Is Dead  Unknown  Kirsten Johnson  Documentaries
#
#          Country show_id   type          date_added  release_year rating  \
# 0  United States      s1  Movie  September 25, 2021          2020  PG-13
#
#   duration year_added      Month
# 0   90 min       2021  September

# %%
# checking the shows released on netflix w.r.t months
df_month=df_shows.groupby(df_final['Month']).agg({"title":"nunique"}).reset_index()
sns.lineplot(data=df_month, x='Month', y='title')
plt.ylabel("Shows Released in the each Month")
plt.xlabel("Months")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Insights
#
# *   the best month to release tv shows on netflix is july and december.
# *   the reason for this might be the semmer and winter vacations.
# *   the data is not sufficient to make decision for business as it is just the
# information of shows added. we need watch time of shows also (is the3 show has been watched by the user or not).
# *  the worst time to add shows on netflix is Febuary and may.

# %%
# checking the movies released on netflix w.r.t months
df_month=df_movies.groupby(df_final['Month']).agg({"title":"nunique"}).reset_index()
sns.lineplot(data=df_month, x='Month', y='title')
plt.ylabel("Movies Released in the each Month")
plt.xlabel("Months")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Insights
#
#
# *   best month to add movies on netflix is july. december, january and october month is also good to add movies on netflix.
# *   wrost month is febuary and may.
# *   again the data is not sufficient to make business decisions.

# %%
df_movies.head()
# Out:
#                                 title             Cast         Director  \
# 0                Dick Johnson Is Dead          Unknown  Kirsten Johnson
# 159  My Little Pony: A New Generation  Vanessa Hudgens    Robert Cullen
# 160  My Little Pony: A New Generation  Vanessa Hudgens   José Luis Ucha
# 161  My Little Pony: A New Generation     Kimiko Glenn    Robert Cullen
# 162  My Little Pony: A New Generation     Kimiko Glenn   José Luis Ucha
#
#                         Genre        Country show_id   type  \
# 0               Documentaries  United States      s1  Movie
# 159  Children & Family Movies  United States      s7  Movie
# 160  Children & Family Movies  United States      s7  Movie
# 161  Children & Family Movies  United States      s7  Movie
# 162  Children & Family Movies  United States      s7  Movie
#
#              date_added  release_year rating duration year_added  _duration  \
# 0    September 25, 2021          2020  PG-13       90       2021         90
# ...

# %%
df_movies['year_added'] = df_movies['year_added'].astype(int)

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 145831 entries, 0 to 201990
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   title          145831 non-null  object
#  1   Cast           145831 non-null  object
#  2   Director       145831 non-null  object
#  3   Genre          145831 non-null  object
#  4   Country        145831 non-null  object
#  5   show_id        145831 non-null  object
#  6   type           145831 non-null  object
#  7   date_added     145831 non-null  object
#  8   release_year   145831 non-null  int64
#  9   rating         145831 non-null  object
#  10  duration       145831 non-null  object
#  11  year_added     145831 non-null  int64
#  12  _duration      145831 non-null  int64
#  13  duration_bins  145831 non-null  category
# dtypes: category(1), int64(3), object(10)
# memory usage: 15.7+ MB

# %%
# checking average time taken for movies to be added on netflix.
time = df_movies['year_added'] - df_movies['release_year']
time.sample(10)
# Out:
# 152673    7
# 115309    2
# 95168     0
# 188321    1
# 139413    2
# 40278     9
# 4441      7
# 92724     0
# 3797      3
# 149374    1
# dtype: int64

# %%
time.mean().round(0)
# Out:
# 7.0

# %% [markdown]
# the average time for movies to be added on netflix is 7 years.

# %%
time.mode()
# Out:
# 0    0
# dtype: int64

# %% [markdown]
# most of the movies are added in the same year as of the release year.

# %%
# checking average time taken for shows to be added on netflix.
df_shows_ = df_shows[['release_year','year_added']]
df_shows_
# Out:
#         release_year year_added
# 1               2021       2021
# 2               2021       2021
# 3               2021       2021
# 4               2021       2021
# 5               2021       2021
# ...              ...        ...
# 201864          2012       2016
# 201865          2012       2016
# 201932          2018       2019
# 201933          2018       2019
# 201934          2018       2019
#
# [56090 rows x 2 columns]

# %%
df_shows_.dropna(inplace=True)

# %%
df_shows_['year_added'] = df_shows_['year_added'].astype(int)

# %%
s_time_ = df_shows_['year_added'] - df_shows_['release_year']
s_time_.sample(10)
# Out:
# 5506       0
# 197970     1
# 16415      0
# 35423      0
# 70724      1
# 88567      0
# 45610      4
# 80284      0
# 65402     34
# 800        0
# dtype: int64

# %%
s_time_.mean().round(0)
# Out:
# 2.0

# %% [markdown]
# the average time for TV Shows to be added on netflix is 2 years.

# %%
from statistics import mode
mode(s_time_)
# Out:
# 0

# %% [markdown]
# most of the TV shows are added in the same year as of the release year.

# %% [markdown]
# # **Analysing the US Movies data**
#
# 1.   List item
# 2.   List item

# %%
# Understanding what content is available in different countries
df_movies.head(1)
# Out:
#                   title     Cast         Director          Genre  \
# 0  Dick Johnson Is Dead  Unknown  Kirsten Johnson  Documentaries
#
#          Country show_id   type          date_added  release_year rating  \
# 0  United States      s1  Movie  September 25, 2021          2020  PG-13
#
#   duration  year_added  _duration duration_bins
# 0       90        2021         90        80-100

# %%
df_m_US = df_movies[df_movies['Country']=='United States']
df_m_US.groupby(df_m_US['Genre']).agg({"title":"nunique"}).reset_index().sort_values(by=['title'],
                                                                                          ascending=False)
# Out:
#                        Genre  title
# 7                     Dramas    945
# 4                   Comedies    774
# 6              Documentaries    586
# 2   Children & Family Movies    496
# 0         Action & Adventure    446
# 10        Independent Movies    401
# 11      International Movies    375
# 19                 Thrillers    320
# 15           Romantic Movies    253
# 18           Stand-Up Comedy    248
# 9              Horror Movies    218
# 14          Music & Musicals    194
# 16          Sci-Fi & Fantasy    182
# 17             Sports Movies    131
# 3             Classic Movies     82
# 12              LGBTQ Movies     68
# 5                Cult Movies     53
# 8       Faith & Spirituality     44
# 13                    Movies     41
# 1             Anime Features     15

# %%
df_m_US.groupby(df_m_US['rating']).agg({"title":"nunique"}).reset_index().sort_values(by=['title'],
                                                                                          ascending=False)
# Out:
#       rating  title
# 8      TV-MA    856
# 5          R    670
# 4      PG-13    441
# 6      TV-14    396
# 3         PG    249
# 9      TV-PG    216
# 11     TV-Y7    111
# 10      TV-Y     99
# 7       TV-G     64
# 2         NR     41
# 0          G     39
# 12  TV-Y7-FV      3
# 1      NC-17      1
# 13        UR      1

# %%
df_m_US.groupby(df_m_US['Cast']).agg({"title":"nunique"}).reset_index().sort_values(by=['title'],
                                                                                          ascending=False)
# Out:
#                            Cast  title
# 12911                   Unknown    321
# 11116              Rupa Bhimani     23
# 6649              Julie Tejwani     23
# 11338         Samuel L. Jackson     22
# 120                Adam Sandler     20
# ...                         ...    ...
# 5245               Jacob Artist      1
# 5246              Jacob Batalon      1
# 5247             Jacob Bertrand      1
# 5248                Jacob Blair      1
# 13481  Łukasz "Lotek” Lodkowski      1
#
# [13482 rows x 2 columns]

# %%
df_m_US.groupby(df_m_US['Director']).agg({"title":"nunique"}).reset_index().sort_values(by=['title'],
                                                                                          ascending=False)
# Out:
#               Director  title
# 2441           Unknown    126
# 1940     Rajiv Chilaka     17
# 1506      Marcus Raboy     15
# 2297       Suhas Kadav     15
# 1004         Jay Karas     15
# ...                ...    ...
# 931      Iwao Takamoto      1
# 930   Ivan Silvestrini      1
# 928      Ismail Farouk      1
# 926    Isabel Sandoval      1
# 2534       Àlex Pastor      1
#
# [2535 rows x 2 columns]

# %% [markdown]
# # **Analysing the US TV shows data**

# %%
df_s_US = df_shows[df_shows['Country']=='United States']
df_s_US.groupby(df_s_US['Genre']).agg({"title":"nunique"}).reset_index().sort_values(by=['title'],
                                                                                          ascending=False)
# Out:
#                            Genre  title
# 14                   TV Comedies    338
# 15                     TV Dramas    332
# 5         International TV Shows    297
# 6                       Kids' TV    295
# 4                     Docuseries    257
# 3                 Crime TV Shows    194
# 8                     Reality TV    173
# 9              Romantic TV Shows    115
# 13         TV Action & Adventure    109
# 18           TV Sci-Fi & Fantasy     65
# 10           Science & Nature TV     59
# 11     Spanish-Language TV Shows     58
# 17                  TV Mysteries     57
# 12  Stand-Up Comedy & Talk Shows     42
# 16                     TV Horror     40
# 0                   Anime Series     40
# 1               British TV Shows     40
# 21                 Teen TV Shows     36
# 20                  TV Thrillers     31
# 7                Korean TV Shows     18
# 2              Classic & Cult TV     18
# 19                      TV Shows     11

# %%
df_s_US.groupby(df_s_US['rating']).agg({"title":"nunique"}).reset_index().sort_values(by=['title'],
                                                                                          ascending=False)
# Out:
#   rating  title
# 4  TV-MA    520
# 2  TV-14    331
# 5  TV-PG    178
# 7  TV-Y7    134
# 6   TV-Y    108
# 3   TV-G     55
# 0     NR      2
# 1      R      1

# %%
df_s_US.groupby(df_s_US['Cast']).agg({"title":"nunique"}).reset_index().sort_values(by=['title'],
                                                                                          ascending=False)[:10]
# Out:
#                           Cast  title
# 6732                   Unknown    239
# 2373              Grey Griffin     10
# 6793              Vincent Tong     10
# 3669  Kevin Michael Richardson      9
# 4679              Michela Luci      8
# 3492             Kari Wahlgren      8
# 3205         Johnny Yong Bosch      8
# 6591                 Tom Kenny      7
# 367              Andrea Libman      7
# 6286               Steven Yeun      7

# %%
df_s_US.groupby(df_s_US['Director']).agg({"title":"nunique"}).reset_index().sort_values(by=['title'],
                                                                                          ascending=False)[:10]
# Out:
#                     Director  title
# 131                  Unknown   1222
# 69                 Ken Burns      3
# 79               Lynn Novick      2
# 105          Rob Seidenglanz      2
# 117              Stan Lathan      2
# 60             Joe Berlinger      2
# 0           Abhishek Chaubey      1
# 88                Noam Murro      1
# 89   Nopparoj Chotmunkongsit      1
# 90              Oliver Stone      1

# %%
"Likewise we can do analysis for other countries."
# Out:
# 'Likewise we can do analysis for other countries.'

# %% [markdown]
# # **Recommendations**
#
# *   Add more movies in the month of july.
# *   Do not add movies in the month of febuary and may.
# *   Add more tv shows in the month of July, december and May.
# *   Do not add tv shows in the month of febuary.
# *   most of the appearing Cast in the dataset belong to India. Therefore Add more number of Indian movies as these actors have huge fans.
# *  Add more movies that have Genre as International movies and Drama and comedy.as these are most appearing Genre in the dataset.
# *  add movies and Tv shows with ratings as TV-MA and TV-14.
# *  add movies that has a duration in the range 50 min - 150 min.
# *  add tv shows that have maximum 3 seasons.
# *  Add more Tv shows that have Genre as International tv shows and Tv Drama and Tv comedy.
# *  old movies can be uploaded in the month of febuary and may. But New movies must be added as soon as possible on netflix as the mode of the time between year released and year added is zero.
# *  Tv shows also must be added in the same year as of the released year.
# *  there has been more focus upon Tv shows as these are added in the same year as of the released.
